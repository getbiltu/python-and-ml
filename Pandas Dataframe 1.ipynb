# %%
import pandas as pd
import numpy as np

# %%
poke=pd.read_csv("Pokemon.csv")
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# # ##Memory Optimisation

# %%
poke['Type 1']=poke['Type 2'].astype('category')
poke['Type 2']=poke['Type 2'].astype('category')
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        414 non-null category
# Type 2        414 non-null category
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(2), int64(9), object(1)
# memory usage: 66.5+ KB

# %%
poke['Total']=poke['Total'].astype('float')
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        414 non-null category
# Type 2        414 non-null category
# Total         800 non-null float64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(2), float64(1), int64(8), object(1)
# memory usage: 66.5+ KB

# %%
poke['Attack']=poke['Attack'].astype('float')
poke['Defense']=poke['Defense'].astype('float')
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        414 non-null category
# Type 2        414 non-null category
# Total         800 non-null float64
# HP            800 non-null int64
# Attack        800 non-null float64
# Defense       800 non-null float64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(2), float64(3), int64(6), object(1)
# memory usage: 66.5+ KB

# %%
poke['new_col']=poke['Total']/10
poke
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur  Poison  Poison  318.0   45    49.0
# 1      2                    Ivysaur  Poison  Poison  405.0   60    62.0
# 2      3                   Venusaur  Poison  Poison  525.0   80    82.0
# 3      3      VenusaurMega Venusaur  Poison  Poison  625.0   80   100.0
# 4      4                 Charmander     NaN     NaN  309.0   39    52.0
# 5      5                 Charmeleon     NaN     NaN  405.0   58    64.0
# 6      6                  Charizard  Flying  Flying  534.0   78    84.0
# 7      6  CharizardMega Charizard X  Dragon  Dragon  634.0   78   130.0
# 8      6  CharizardMega Charizard Y  Flying  Flying  634.0   78   104.0
# 9      7                   Squirtle     NaN     NaN  314.0   44    48.0
# 10     8                  Wartortle     NaN     NaN  405.0   59    63.0
# 11     9                  Blastoise     NaN     NaN  530.0   79    83.0
# ...

# %%
poke.insert(3,column='Channel',value='Cartoon Network')

# %%
poke
# Out:
#        #                       Name  Type 1          Channel  Type 2  Total  \
# 0      1                  Bulbasaur  Poison  Cartoon Network  Poison  318.0
# 1      2                    Ivysaur  Poison  Cartoon Network  Poison  405.0
# 2      3                   Venusaur  Poison  Cartoon Network  Poison  525.0
# 3      3      VenusaurMega Venusaur  Poison  Cartoon Network  Poison  625.0
# 4      4                 Charmander     NaN  Cartoon Network     NaN  309.0
# 5      5                 Charmeleon     NaN  Cartoon Network     NaN  405.0
# 6      6                  Charizard  Flying  Cartoon Network  Flying  534.0
# 7      6  CharizardMega Charizard X  Dragon  Cartoon Network  Dragon  634.0
# 8      6  CharizardMega Charizard Y  Flying  Cartoon Network  Flying  634.0
# 9      7                   Squirtle     NaN  Cartoon Network     NaN  314.0
# 10     8                  Wartortle     NaN  Cartoon Network     NaN  405.0
# ...

# %%
poke.insert(5,column='Test',value='None')

# %%
poke
# Out:
#        #                       Name  Type 1          Channel  Type 2  Test  \
# 0      1                  Bulbasaur  Poison  Cartoon Network  Poison  None
# 1      2                    Ivysaur  Poison  Cartoon Network  Poison  None
# 2      3                   Venusaur  Poison  Cartoon Network  Poison  None
# 3      3      VenusaurMega Venusaur  Poison  Cartoon Network  Poison  None
# 4      4                 Charmander     NaN  Cartoon Network     NaN  None
# 5      5                 Charmeleon     NaN  Cartoon Network     NaN  None
# 6      6                  Charizard  Flying  Cartoon Network  Flying  None
# 7      6  CharizardMega Charizard X  Dragon  Cartoon Network  Dragon  None
# 8      6  CharizardMega Charizard Y  Flying  Cartoon Network  Flying  None
# 9      7                   Squirtle     NaN  Cartoon Network     NaN  None
# 10     8                  Wartortle     NaN  Cartoon Network     NaN  None
# ...

# %%
poke.set_index('Name',inplace=True)

# %%
poke
# Out:
#                              #  Type 1          Channel  Type 2  Test  Total  \
# Name
# Bulbasaur                    1  Poison  Cartoon Network  Poison  None  318.0
# Ivysaur                      2  Poison  Cartoon Network  Poison  None  405.0
# Venusaur                     3  Poison  Cartoon Network  Poison  None  525.0
# VenusaurMega Venusaur        3  Poison  Cartoon Network  Poison  None  625.0
# Charmander                   4     NaN  Cartoon Network     NaN  None  309.0
# Charmeleon                   5     NaN  Cartoon Network     NaN  None  405.0
# Charizard                    6  Flying  Cartoon Network  Flying  None  534.0
# CharizardMega Charizard X    6  Dragon  Cartoon Network  Dragon  None  634.0
# CharizardMega Charizard Y    6  Flying  Cartoon Network  Flying  None  634.0
# Squirtle                     7     NaN  Cartoon Network     NaN  None  314.0
# Wartortle                    8     NaN  Cartoon Network     NaN  None  405.0
# ...

# %%
poke.reset_index()
# Out:
#                           Name    #  Type 1          Channel  Type 2  Test  \
# 0                    Bulbasaur    1  Poison  Cartoon Network  Poison  None
# 1                      Ivysaur    2  Poison  Cartoon Network  Poison  None
# 2                     Venusaur    3  Poison  Cartoon Network  Poison  None
# 3        VenusaurMega Venusaur    3  Poison  Cartoon Network  Poison  None
# 4                   Charmander    4     NaN  Cartoon Network     NaN  None
# 5                   Charmeleon    5     NaN  Cartoon Network     NaN  None
# 6                    Charizard    6  Flying  Cartoon Network  Flying  None
# 7    CharizardMega Charizard X    6  Dragon  Cartoon Network  Dragon  None
# 8    CharizardMega Charizard Y    6  Flying  Cartoon Network  Flying  None
# 9                     Squirtle    7     NaN  Cartoon Network     NaN  None
# 10                   Wartortle    8     NaN  Cartoon Network     NaN  None
# ...

# %%
poke['Total']>200
# Out:
# Name
# Bulbasaur                     True
# Ivysaur                       True
# Venusaur                      True
# VenusaurMega Venusaur         True
# Charmander                    True
# Charmeleon                    True
# Charizard                     True
# CharizardMega Charizard X     True
# CharizardMega Charizard Y     True
# Squirtle                      True
# Wartortle                     True
# Blastoise                     True
# BlastoiseMega Blastoise       True
# Caterpie                     False
# Metapod                       True
# Butterfree                    True
# Weedle                       False
# Kakuna                        True
# Beedrill                      True
# BeedrillMega Beedrill         True
# Pidgey                        True
# Pidgeotto                     True
# Pidgeot                       True
# PidgeotMega Pidgeot           True
# Rattata                       True
# Raticate                      True
# ...

# %%
type(poke['Total']>200)
# Out:
# pandas.core.series.Series

# %%
mask=poke['Total']>200
poke[mask]
# Out:
#                              #  Type 1          Channel  Type 2  Test  Total  \
# Name
# Bulbasaur                    1  Poison  Cartoon Network  Poison  None  318.0
# Ivysaur                      2  Poison  Cartoon Network  Poison  None  405.0
# Venusaur                     3  Poison  Cartoon Network  Poison  None  525.0
# VenusaurMega Venusaur        3  Poison  Cartoon Network  Poison  None  625.0
# Charmander                   4     NaN  Cartoon Network     NaN  None  309.0
# Charmeleon                   5     NaN  Cartoon Network     NaN  None  405.0
# Charizard                    6  Flying  Cartoon Network  Flying  None  534.0
# CharizardMega Charizard X    6  Dragon  Cartoon Network  Dragon  None  634.0
# CharizardMega Charizard Y    6  Flying  Cartoon Network  Flying  None  634.0
# Squirtle                     7     NaN  Cartoon Network     NaN  None  314.0
# Wartortle                    8     NaN  Cartoon Network     NaN  None  405.0
# ...

# %%
mask
# Out:
# Name
# Bulbasaur                     True
# Ivysaur                       True
# Venusaur                      True
# VenusaurMega Venusaur         True
# Charmander                    True
# Charmeleon                    True
# Charizard                     True
# CharizardMega Charizard X     True
# CharizardMega Charizard Y     True
# Squirtle                      True
# Wartortle                     True
# Blastoise                     True
# BlastoiseMega Blastoise       True
# Caterpie                     False
# Metapod                       True
# Butterfree                    True
# Weedle                       False
# Kakuna                        True
# Beedrill                      True
# BeedrillMega Beedrill         True
# Pidgey                        True
# Pidgeotto                     True
# Pidgeot                       True
# PidgeotMega Pidgeot           True
# Rattata                       True
# Raticate                      True
# ...

# %%
mask1=poke['Total']>300

# %%
mask3=poke['Type 1']=='Grass'
mask4=poke['Type 2']=='Fire'

# %%
poke[mask1 & (mask3 | mask4)]
# Out:
#                          # Type 1          Channel Type 2  Test  Total   HP  \
# Name
# Parasect                47  Grass  Cartoon Network  Grass  None  405.0   60
# Houndour               228   Fire  Cartoon Network   Fire  None  330.0   45
# Houndoom               229   Fire  Cartoon Network   Fire  None  500.0   75
# HoundoomMega Houndoom  229   Fire  Cartoon Network   Fire  None  600.0   75
# Celebi                 251  Grass  Cartoon Network  Grass  None  600.0  100
# Lombre                 271  Grass  Cartoon Network  Grass  None  340.0   60
# Ludicolo               272  Grass  Cartoon Network  Grass  None  480.0   80
# Lileep                 345  Grass  Cartoon Network  Grass  None  355.0   66
# Cradily                346  Grass  Cartoon Network  Grass  None  495.0   86
# GroudonPrimal Groudon  383   Fire  Cartoon Network   Fire  None  770.0  100
# WormadamPlant Cloak    413  Grass  Cartoon Network  Grass  None  424.0   60
# ...

# %%
poke[['Type 1','Type 2']]
# Out:
#                            Type 1  Type 2
# Name
# Bulbasaur                  Poison  Poison
# Ivysaur                    Poison  Poison
# Venusaur                   Poison  Poison
# VenusaurMega Venusaur      Poison  Poison
# Charmander                    NaN     NaN
# Charmeleon                    NaN     NaN
# Charizard                  Flying  Flying
# CharizardMega Charizard X  Dragon  Dragon
# CharizardMega Charizard Y  Flying  Flying
# Squirtle                      NaN     NaN
# Wartortle                     NaN     NaN
# Blastoise                     NaN     NaN
# BlastoiseMega Blastoise       NaN     NaN
# Caterpie                      NaN     NaN
# Metapod                       NaN     NaN
# Butterfree                 Flying  Flying
# Weedle                     Poison  Poison
# Kakuna                     Poison  Poison
# Beedrill                   Poison  Poison
# BeedrillMega Beedrill      Poison  Poison
# Pidgey                     Flying  Flying
# ...

# %%
poke['Type 1']
# Out:
# Name
# Bulbasaur                    Poison
# Ivysaur                      Poison
# Venusaur                     Poison
# VenusaurMega Venusaur        Poison
# Charmander                      NaN
# Charmeleon                      NaN
# Charizard                    Flying
# CharizardMega Charizard X    Dragon
# CharizardMega Charizard Y    Flying
# Squirtle                        NaN
# Wartortle                       NaN
# Blastoise                       NaN
# BlastoiseMega Blastoise         NaN
# Caterpie                        NaN
# Metapod                         NaN
# Butterfree                   Flying
# Weedle                       Poison
# Kakuna                       Poison
# Beedrill                     Poison
# BeedrillMega Beedrill        Poison
# Pidgey                       Flying
# Pidgeotto                    Flying
# Pidgeot                      Flying
# PidgeotMega Pidgeot          Flying
# Rattata                         NaN
# Raticate                        NaN
# ...

# %%
poke[mask1 & (mask3 | mask4)]
# Out:
#   File "<ipython-input-48-81f8840101ed>", line 1
#     poke[mask1 ! (mask3 | mask4)]
#                ^
# SyntaxError: invalid syntax

# %%
mask3=poke['Type 1']!='Grass'
mask4=poke['Type 2']!='Fire'

# %%
poke[mask1 & (mask3 | mask4)]
# Out:
#                              #  Type 1          Channel  Type 2  Test  Total  \
# Name
# Bulbasaur                    1  Poison  Cartoon Network  Poison  None  318.0
# Ivysaur                      2  Poison  Cartoon Network  Poison  None  405.0
# Venusaur                     3  Poison  Cartoon Network  Poison  None  525.0
# VenusaurMega Venusaur        3  Poison  Cartoon Network  Poison  None  625.0
# Charmander                   4     NaN  Cartoon Network     NaN  None  309.0
# Charmeleon                   5     NaN  Cartoon Network     NaN  None  405.0
# Charizard                    6  Flying  Cartoon Network  Flying  None  534.0
# CharizardMega Charizard X    6  Dragon  Cartoon Network  Dragon  None  634.0
# CharizardMega Charizard Y    6  Flying  Cartoon Network  Flying  None  634.0
# Squirtle                     7     NaN  Cartoon Network     NaN  None  314.0
# Wartortle                    8     NaN  Cartoon Network     NaN  None  405.0
# ...

# %%
poke["Total"].rank(ascending=False).astype('int')
# Out:
# Name
# Bulbasaur                    628
# Ivysaur                      479
# Venusaur                     169
# VenusaurMega Venusaur         42
# Charmander                   653
# Charmeleon                   479
# Charizard                    145
# CharizardMega Charizard X     36
# CharizardMega Charizard Y     36
# Squirtle                     637
# Wartortle                    479
# Blastoise                    153
# BlastoiseMega Blastoise       39
# Caterpie                     796
# Metapod                      788
# Butterfree                   501
# Weedle                       796
# Kakuna                       788
# Beedrill                     501
# BeedrillMega Beedrill        261
# Pidgey                       757
# Pidgeotto                    561
# Pidgeot                      333
# PidgeotMega Pidgeot          114
# Rattata                      756
# Raticate                     453
# Spearow                      750
# Fearow                       407
# ...

# %%
poke['Ranking']=poke["Total"].rank(ascending=False).astype('int')

# %%
poke
# Out:
#                              #  Type 1          Channel  Type 2  Test  Total  \
# Name
# Bulbasaur                    1  Poison  Cartoon Network  Poison  None  318.0
# Ivysaur                      2  Poison  Cartoon Network  Poison  None  405.0
# Venusaur                     3  Poison  Cartoon Network  Poison  None  525.0
# VenusaurMega Venusaur        3  Poison  Cartoon Network  Poison  None  625.0
# Charmander                   4     NaN  Cartoon Network     NaN  None  309.0
# Charmeleon                   5     NaN  Cartoon Network     NaN  None  405.0
# Charizard                    6  Flying  Cartoon Network  Flying  None  534.0
# CharizardMega Charizard X    6  Dragon  Cartoon Network  Dragon  None  634.0
# CharizardMega Charizard Y    6  Flying  Cartoon Network  Flying  None  634.0
# Squirtle                     7     NaN  Cartoon Network     NaN  None  314.0
# Wartortle                    8     NaN  Cartoon Network     NaN  None  405.0
# ...

# %%
poke['Total'].sort_values(ascending=False).head(5)
# Out:
# Name
# MewtwoMega Mewtwo X      780.0
# RayquazaMega Rayquaza    780.0
# MewtwoMega Mewtwo Y      780.0
# KyogrePrimal Kyogre      770.0
# GroudonPrimal Groudon    770.0
# Name: Total, dtype: float64

# %%
poke.sort_values('Ranking',ascending=False).head(5)
# Out:
#              #  Type 1          Channel  Type 2  Test  Total  HP  Attack  \
# Name
# Sunkern    191     NaN  Cartoon Network     NaN  None  180.0  30    30.0
# Azurill    298   Fairy  Cartoon Network   Fairy  None  190.0  50    20.0
# Kricketot  401     NaN  Cartoon Network     NaN  None  194.0  37    25.0
# Wurmple    265     NaN  Cartoon Network     NaN  None  195.0  45    45.0
# Weedle      13  Poison  Cartoon Network  Poison  None  195.0  40    35.0
#
#            Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  new_col  \
# Name
# Sunkern       30.0       30       30     30           2      False     18.0
# Azurill       40.0       20       40     20           3      False     19.0
# Kricketot     41.0       25       41     25           4      False     19.4
# Wurmple       35.0       20       30     20           3      False     19.5
# Weedle        30.0       20       20     50           1      False     19.5
#
#            Ranking
# Name
# Sunkern        800
# ...

# %%
poke.rename({'Type 1':'Category'},axis=1)
# Out:
#                              # Category          Channel  Type 2  Test  Total  \
# Name
# Bulbasaur                    1   Poison  Cartoon Network  Poison  None  318.0
# Ivysaur                      2   Poison  Cartoon Network  Poison  None  405.0
# Venusaur                     3   Poison  Cartoon Network  Poison  None  525.0
# VenusaurMega Venusaur        3   Poison  Cartoon Network  Poison  None  625.0
# Charmander                   4      NaN  Cartoon Network     NaN  None  309.0
# Charmeleon                   5      NaN  Cartoon Network     NaN  None  405.0
# Charizard                    6   Flying  Cartoon Network  Flying  None  534.0
# CharizardMega Charizard X    6   Dragon  Cartoon Network  Dragon  None  634.0
# CharizardMega Charizard Y    6   Flying  Cartoon Network  Flying  None  634.0
# Squirtle                     7      NaN  Cartoon Network     NaN  None  314.0
# Wartortle                    8      NaN  Cartoon Network     NaN  None  405.0
# ...

# %%
poke.rename({'Type 2':'Sub-Category'},axis=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-b6889fdfebdf> in <module>()
# ----> 1 poke.rename({'Type 2':'Sub-Category'},axis=2)
#
# D:\Installed_Apps\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     184         @wraps(func)
#     185         def wrapper(*args, **kwargs):
# --> 186             return func(*args, **kwargs)
#     187
#     188         if not PY2:
#
# D:\Installed_Apps\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    3771         4  3  6
#    3772         """
# -> 3773         axes = validate_axis_style_args(self, args, kwargs, 'mapper', 'rename')
#    3774         kwargs.update(axes)
#    3775         # Pop these, since the values are in `kwargs` under different names
#
# ...

# %%
poke['Type 1'].unique()
# Out:
# [Poison, NaN, Flying, Dragon, Ground, ..., Electric, Fire, Ghost, Bug, Normal]
# Length: 19
# Categories (18, object): [Poison, Flying, Dragon, Ground, ..., Fire, Ghost, Bug, Normal]

# %%
poke['Type 1'].nunique()
# Out:
# 18

# %%
poke1=pd.read_csv('Pokemon.csv')

# %%
poke1['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
poke1['Type 1'].nunique()
# Out:
# 18

# %%
poke1.drop_duplicates('Type 1')
# Out:
#        #                     Name    Type 1   Type 2  Total  HP  Attack  \
# 0      1                Bulbasaur     Grass   Poison    318  45      49
# 4      4               Charmander      Fire      NaN    309  39      52
# 9      7                 Squirtle     Water      NaN    314  44      48
# 13    10                 Caterpie       Bug      NaN    195  45      30
# 20    16                   Pidgey    Normal   Flying    251  40      45
# 28    23                    Ekans    Poison      NaN    288  35      60
# 30    25                  Pikachu  Electric      NaN    320  35      55
# 32    27                Sandshrew    Ground      NaN    300  50      75
# 40    35                 Clefairy     Fairy      NaN    323  70      45
# 61    56                   Mankey  Fighting      NaN    305  40      80
# 68    63                     Abra   Psychic      NaN    310  25      20
# 80    74                  Geodude      Rock   Ground    300  40      80
# ...

# %%
len(poke1.drop_duplicates('Type 1'))
# Out:
# 18

# %%
poke1.drop_duplicates(['Type 1','Type 2'])
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 4      4                 Charmander      Fire       NaN    309   39      52
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 9      7                   Squirtle     Water       NaN    314   44      48
# 13    10                   Caterpie       Bug       NaN    195   45      30
# 15    12                 Butterfree       Bug    Flying    395   60      45
# 16    13                     Weedle       Bug    Poison    195   40      35
# 20    16                     Pidgey    Normal    Flying    251   40      45
# 24    19                    Rattata    Normal       NaN    253   30      56
# 28    23                      Ekans    Poison       NaN    288   35      60
# ...

# %%
len(poke1.drop_duplicates(['Type 1','Type 2']))
# Out:
# 154

# %%
poke1.drop('Generation',axis=1)
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
poke1.drop(['Generation','Speed'],axis=1)
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
poke1.drop(3)
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# 12     9    BlastoiseMega Blastoise     Water     NaN    630   79     103
# ...

# %%
movie=pd.read_csv('BollywoodMovieDetail.csv')

# %%
movie.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
##multi Index
movie.set_index(['genre','title'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Installed_Apps\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-9e00e280fcd4> in <module>()
#       1 ##multi Index
# ...

# %%
movie.sort_index()
# Out:
#                                                                                       imdbId  \
# genre                          title
# Action                         Aakhri Inteqam                                      tt0426864
#                                Agent Vinod                                         tt1395025
#                                Angaar: The Fire                                    tt0315767
#                                Angry Young Man                                     tt3617048
#                                Ashok Chakra: Tribute to Real Heroes                tt2011871
#                                Bhairav                                             tt0466208
#                                Chakradhaar                                         tt2207668
#                                Department                                          tt2186731
#                                Desi Kattey                                         tt3877652
# ...

# %%
type(movie.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
poke1.set_axis('Name',inplace=True)

# %%
poke1.loc['Wartortle']
# Out:
# #                 8
# Type 1        Water
# Type 2          NaN
# Total           405
# HP               59
# Attack           63
# Defense          80
# Sp. Atk          65
# Sp. Def          80
# Speed            58
# Generation        1
# Legendary     False
# Name: Wartortle, dtype: object

# %%
poke1.loc['Wartortle':]
# Out:
#                            #    Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Wartortle                  8     Water     NaN    405   59      63       80
# Blastoise                  9     Water     NaN    530   79      83      100
# BlastoiseMega Blastoise    9     Water     NaN    630   79     103      120
# Caterpie                  10       Bug     NaN    195   45      30       35
# Metapod                   11       Bug     NaN    205   50      20       55
# Butterfree                12       Bug  Flying    395   60      45       50
# Weedle                    13       Bug  Poison    195   40      35       30
# Kakuna                    14       Bug  Poison    205   45      25       50
# Beedrill                  15       Bug  Poison    395   65      90       40
# BeedrillMega Beedrill     15       Bug  Poison    495   65     150       40
# Pidgey                    16    Normal  Flying    251   40      45       40
# ...

# %%
poke1.iloc[5]
# Out:
# #                 5
# Type 1         Fire
# Type 2          NaN
# Total           405
# HP               58
# Attack           64
# Defense          58
# Sp. Atk          80
# Sp. Def          65
# Speed            80
# Generation        1
# Legendary     False
# Name: Charmeleon, dtype: object

# %%
poke1.iloc[5]['Total']
# Out:
# 405

# %%
poke1.ix['Wartortle']['Total']
# Out:
# D:\Installed_Apps\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 405

# %%
poke1.ix[5]['Total']
# Out:
# D:\Installed_Apps\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 405

# %%
movie.sort_index(inplace=True)

# %%
movie
# Out:
#                                                                                       imdbId  \
# genre                          title
# Action                         Aakhri Inteqam                                      tt0426864
#                                Agent Vinod                                         tt1395025
#                                Angaar: The Fire                                    tt0315767
#                                Angry Young Man                                     tt3617048
#                                Ashok Chakra: Tribute to Real Heroes                tt2011871
#                                Bhairav                                             tt0466208
#                                Chakradhaar                                         tt2207668
#                                Department                                          tt2186731
#                                Desi Kattey                                         tt3877652
# ...

# %%
movie.loc['Action',"Agent Vinod"]
# Out:
# imdbId                                                 tt1395025
# releaseYear                                                 2012
# releaseDate                                          23 Mar 2012
# writers          Arijit Biswas (story) | Sriram Raghavan (story)
# actors         Kareena Kapoor | Saif Ali Khan | Adil Hussain ...
# directors                                        Sriram Raghavan
# sequel                                                         0
# hitFlop                                                        2
# Name: (Action, Agent Vinod), dtype: object

# %%
movie.loc['Action',"Agent Vinod"][7]
# Out:
# 2

# %%
movie.loc["Action","Agent Vinod"]
# Out:
# imdbId                                                 tt1395025
# releaseYear                                                 2012
# releaseDate                                          23 Mar 2012
# writers          Arijit Biswas (story) | Sriram Raghavan (story)
# actors         Kareena Kapoor | Saif Ali Khan | Adil Hussain ...
# directors                                        Sriram Raghavan
# sequel                                                         0
# hitFlop                                                        2
# Name: (Action, Agent Vinod), dtype: object

# %%
movie.stack()
# Out:
# genre                  title
# Action                 Aakhri Inteqam                        imdbId                                                 tt0426864
#                                                              releaseYear                                                 2002
#                                                              writers                                            Rajesh Bakshi
#                                                              actors         Sudesh Berry | Anu Kashyap | Amit Pachori | Ji...
#                                                              directors                                          Rajesh Bakshi
#                                                              sequel                                                         0
#                                                              hitFlop                                                        1
# ...

# %%
movie=movie.drop(['imdbId','releaseYear','releaseDate','writers','actors','sequel'],axis=1)

# %%
movie.stack()
# Out:
# genre                           title
# Action                          Aakhri Inteqam                                      directors                                        Rajesh Bakshi
#                                                                                     hitFlop                                                      1
#                                 Agent Vinod                                         directors                                      Sriram Raghavan
#                                                                                     hitFlop                                                      2
#                                 Angaar: The Fire                                    directors                                         Ajay Kashyap
#                                                                                     hitFlop                                                      1
# ...

# %%
len(movie.stack())
# Out:
# 2564

# %%
type(movie.stack())
# Out:
# pandas.core.series.Series

# %%
movie.stack().to_frame()
# Out:
#                                                                                                                                              0
# genre                          title
# Action                         Aakhri Inteqam                                     directors                                      Rajesh Bakshi
#                                                                                   hitFlop                                                    1
#                                Agent Vinod                                        directors                                    Sriram Raghavan
#                                                                                   hitFlop                                                    2
#                                Angaar: The Fire                                   directors                                       Ajay Kashyap
# ...

# %%
movie=movie.stack().to_frame()

# %%
movie
# Out:
#                                                                                                                                              0
# genre                          title
# Action                         Aakhri Inteqam                                     directors                                      Rajesh Bakshi
#                                                                                   hitFlop                                                    1
#                                Agent Vinod                                        directors                                    Sriram Raghavan
#                                                                                   hitFlop                                                    2
#                                Angaar: The Fire                                   directors                                       Ajay Kashyap
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2564 entries, (Action, Aakhri Inteqam, directors) to (nan, Zed Plus, hitFlop)
# Data columns (total 1 columns):
# 0    2564 non-null object
# dtypes: object(1)
# memory usage: 44.4+ KB

# %%
movie.rename({0:"Details"},axis=1)
# Out:
#                                                                                                                                        Details
# genre                          title
# Action                         Aakhri Inteqam                                     directors                                      Rajesh Bakshi
#                                                                                   hitFlop                                                    1
#                                Agent Vinod                                        directors                                    Sriram Raghavan
#                                                                                   hitFlop                                                    2
#                                Angaar: The Fire                                   directors                                       Ajay Kashyap
# ...

# %%
movie.rename({0:"Names"},axis=1)
# Out:
#                                                                                                                                          Names
# genre                          title
# Action                         Aakhri Inteqam                                     directors                                      Rajesh Bakshi
#                                                                                   hitFlop                                                    1
#                                Agent Vinod                                        directors                                    Sriram Raghavan
#                                                                                   hitFlop                                                    2
#                                Angaar: The Fire                                   directors                                       Ajay Kashyap
# ...

# %%
movie.unstack()
# Out:
#                                                                                                                                    0  \
#                                                                                                                            directors
# genre                          title
# NaN                            Shuruaat Ka Interval                                Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
#                                Zed Plus                                                                      Chandra Prakash Dwivedi
# Action                         Aakhri Inteqam                                                                          Rajesh Bakshi
#                                Agent Vinod                                                                           Sriram Raghavan
#                                Angaar: The Fire                                                                         Ajay Kashyap
# ...

# %%
movie.unstack()
# Out:
#                                                                                                                                    0  \
#                                                                                                                            directors
# genre                          title
# NaN                            Shuruaat Ka Interval                                Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
#                                Zed Plus                                                                      Chandra Prakash Dwivedi
# Action                         Aakhri Inteqam                                                                          Rajesh Bakshi
#                                Agent Vinod                                                                           Sriram Raghavan
#                                Angaar: The Fire                                                                         Ajay Kashyap
# ...

# %%
movie.unstack().unstack()
# Out:
#                                              0                              \
#                                      directors
# title                                ...Yahaan 13B: Fear Has a New Address
# genre
# NaN                                        NaN                         NaN
# Action                                     NaN                         NaN
# Action | Adventure                         NaN                         NaN
# Action | Adventure | Biography             NaN                         NaN
# Action | Adventure | Comedy                NaN                         NaN
# Action | Adventure | Crime                 NaN                         NaN
# Action | Adventure | Drama                 NaN                         NaN
# Action | Adventure | Fantasy               NaN                         NaN
# Action | Adventure | Romance               NaN                         NaN
# Action | Adventure | Sci-Fi                NaN                         NaN
# ...

# %%
movie.unstack().unstack().unstack()
# Out:
#               title      genre
# 0  directors  ...Yahaan  NaN                               NaN
#                          Action                            NaN
#                          Action | Adventure                NaN
#                          Action | Adventure | Biography    NaN
#                          Action | Adventure | Comedy       NaN
#                          Action | Adventure | Crime        NaN
#                          Action | Adventure | Drama        NaN
#                          Action | Adventure | Fantasy      NaN
#                          Action | Adventure | Romance      NaN
#                          Action | Adventure | Sci-Fi       NaN
#                          Action | Adventure | Thriller     NaN
#                          Action | Comedy                   NaN
#                          Action | Comedy | Crime           NaN
#                          Action | Comedy | Drama           NaN
# ...

# %%
type(movie.unstack().unstack().unstack()).
# Out:
# pandas.core.series.Series

# %%
movie.unstack().unstack().unstack().to_frame()
# Out:
#                                                         0
#             title     genre
# 0 directors ...Yahaan NaN                             NaN
#                       Action                          NaN
#                       Action | Adventure              NaN
#                       Action | Adventure | Biography  NaN
#                       Action | Adventure | Comedy     NaN
#                       Action | Adventure | Crime      NaN
#                       Action | Adventure | Drama      NaN
#                       Action | Adventure | Fantasy    NaN
#                       Action | Adventure | Romance    NaN
#                       Action | Adventure | Sci-Fi     NaN
#                       Action | Adventure | Thriller   NaN
#                       Action | Comedy                 NaN
#                       Action | Comedy | Crime         NaN
#                       Action | Comedy | Drama         NaN
#                       Action | Comedy | Musical       NaN
# ...

# %%
type(movie.unstack().unstack().unstack())
# Out:
# pandas.core.series.Series

# %%
len(movie.unstack().unstack().unstack())
# Out:
# 554688

# %%
food=pd.read_csv("food.csv")

# %%
food
# Out:
#          Name Gender     City Frequency      Item  Spends
# 0      Nitish      M  Kolkata    Weekly    Burger      11
# 1         Anu      F  Gurgaon     Daily  Sandwich      14
# 2       Mukku      M  Kolkata      Once      Vada      25
# 3        Suri      M  Kolkata   Monthly     Pizza      56
# 4       Rajiv      M    Patna     Never    Paneer      34
# 5    Vandanda      F    Patna      Once   Chicken      23
# 6      Piyush      M   Ranchi     Never   Chicken      67
# 7     Radhika      F   Mumbai   Monthly     Pizza      43
# 8       Sunil      M   Mumbai   Monthly      Vada      34
# 9     Madhuri      F     Pune     Daily    Paneer      66
# 10      Sonal      F     Pune   Monthly     Pizza      89
# 11      Abhay      M    Patna     Daily    Burger      65
# 12     Vineet      M   Ranchi      Once  Sandwich      34
# 13      Sumit      M  Gurgaon     Never  Sandwich      34
# 14     Ranbir      M   Mumbai    Weekly      Vada      55
# ...

# %%
food.pivot_table(values='Spends',index='Gender',aggfunc='mean')
# Out:
#            Spends
# Gender
# F       57.300000
# M       54.433333

# %%
food.pivot_table(values='Spends',index=['Gender','City'],aggfunc='mean')
# Out:
#                    Spends
# Gender City
# F      Chennai  33.333333
#        Gurgaon  50.000000
#        Kolkata  63.000000
#        Mumbai   43.000000
#        Patna    52.500000
#        Pune     67.500000
#        Ranchi   90.000000
# M      Chennai  52.000000
#        Gurgaon  63.000000
#        Kolkata  49.142857
#        Mumbai   49.400000
#        Patna    53.000000
#        Pune     78.000000
#        Ranchi   58.400000

# %%
food.pivot_table(values='Spends',index=['Gender','Item'],aggfunc='mean')
# Out:
#                     Spends
# Gender Item
# F      Burger    61.333333
#        Chicken   23.000000
#        Paneer    61.666667
#        Pizza     62.571429
#        Sandwich  41.000000
#        Vada      64.333333
# M      Burger    37.800000
#        Chicken   67.000000
#        Paneer    49.800000
#        Pizza     66.250000
#        Sandwich  62.142857
#        Vada      53.500000

# %%
food.pivot_table(values='Spends',index=['Gender','Item'],columns='City',aggfunc='mean')
# Out:
# City             Chennai    Gurgaon    Kolkata  Mumbai  Patna       Pune  \
# Gender Item
# F      Burger        NaN        NaN  63.000000     NaN   60.5        NaN
#        Chicken       NaN        NaN        NaN     NaN   23.0        NaN
#        Paneer        NaN        NaN        NaN     NaN    NaN  61.666667
#        Pizza        34.0        NaN        NaN    43.0    NaN  67.750000
#        Sandwich     43.0  14.000000        NaN     NaN   66.0        NaN
#        Vada         23.0  86.000000        NaN     NaN    NaN  84.000000
# M      Burger       44.0        NaN  11.000000    21.0   56.5        NaN
#        Chicken       NaN        NaN        NaN     NaN    NaN        NaN
#        Paneer       67.0        NaN        NaN    38.0   34.0  78.000000
#        Pizza        54.0        NaN  56.000000    99.0    NaN        NaN
#        Sandwich     43.0  76.666667  54.000000     NaN    NaN        NaN
#        Vada          NaN  22.000000  55.666667    44.5   65.0        NaN
#
# ...

# %%
food.pivot_table(values='Spends',index=['Gender','Item'],columns=['City','Frequency'],aggfunc='mean')
# Out:
# City            Chennai                      Gurgaon                      \
# Frequency         Daily Monthly  Once Weekly   Daily Monthly Never  Once
# Gender Item
# F      Burger       NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Chicken      NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Paneer       NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Pizza       34.0     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Sandwich     NaN     NaN   NaN   43.0    14.0     NaN   NaN   NaN
#        Vada         NaN     NaN  23.0    NaN     NaN    86.0   NaN   NaN
# M      Burger       NaN     NaN  44.0    NaN     NaN     NaN   NaN   NaN
#        Chicken      NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Paneer       NaN    67.0   NaN    NaN     NaN     NaN   NaN   NaN
#        Pizza        NaN     NaN  54.0    NaN     NaN     NaN   NaN   NaN
#        Sandwich     NaN    43.0   NaN    NaN     NaN     NaN  34.0  98.0
# ...

# %%
(food.pivot_table(values='Spends',index=['Gender','Item'],columns=['City','Frequency'],aggfunc='mean')).shape
# Out:
# (12, 29)

# %%
food.pivot_table(values='Spends',index=['Gender','Item'],columns=['City','Frequency'],aggfunc='min')
# Out:
# City            Chennai                      Gurgaon                      \
# Frequency         Daily Monthly  Once Weekly   Daily Monthly Never  Once
# Gender Item
# F      Burger       NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Chicken      NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Paneer       NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Pizza       34.0     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Sandwich     NaN     NaN   NaN   43.0    14.0     NaN   NaN   NaN
#        Vada         NaN     NaN  23.0    NaN     NaN    86.0   NaN   NaN
# M      Burger       NaN     NaN  44.0    NaN     NaN     NaN   NaN   NaN
#        Chicken      NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#        Paneer       NaN    67.0   NaN    NaN     NaN     NaN   NaN   NaN
#        Pizza        NaN     NaN  54.0    NaN     NaN     NaN   NaN   NaN
#        Sandwich     NaN    43.0   NaN    NaN     NaN     NaN  34.0  97.0
# ...

# %%
order1=pd.read_csv('order_week1.csv')

# %%
order2=pd.read_csv('order_week2.csv')

# %%
order1.head()
# Out:
#    Customer Id  Food Id
# 0          400        2
# 1          137        2
# 2          195        7
# 3          550        5
# 4          316        8

# %%
order2.head()
# Out:
#    Customer Id  Food Id
# 0          518        6
# 1          248        7
# 2          555        7
# 3          211        1
# 4          448        2

# %%
pd.concat([order1,order2])
# Out:
#      Customer Id  Food Id
# 0            400        2
# 1            137        2
# 2            195        7
# 3            550        5
# 4            316        8
# 5            303        9
# 6            474        4
# 7            466        4
# 8            364        8
# 9            497        9
# 10           406        3
# 11           116        7
# 12           429        6
# 13           258        4
# 14            80        2
# 15           230        8
# 16            57        3
# 17           467        7
# 18           139        3
# 19           245        2
# 20           166        9
# 21           588        5
# 22           217        7
# 23           453        1
# 24           274        6
# 25           297        8
# 26           598        7
# 27            70        8
# 28           492        9
# 29           159        1
# ..           ...      ...
# 219          306        6
# 220          119        2
# 221          313        2
# ...

# %%
pd.concat([order1,order2]).tail()
# Out:
#      Customer Id  Food Id
# 244          205        8
# 245          219        1
# 246          155        1
# 247          291        7
# 248          305        6

# %%
pd.concat([order1,order2],ignore_index=True).tail()
# Out:
#      Customer Id  Food Id
# 493          205        8
# 494          219        1
# 495          155        1
# 496          291        7
# 497          305        6

# %%
df3=pd.concat([order1,order2],ignore_index=True,keys=('A','B'))

# %%
df3.loc[36]
# Out:
# Customer Id    471
# Food Id          7
# Name: 36, dtype: int64
